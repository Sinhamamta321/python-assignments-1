# %%
# Read this Dataset

# %%
# Write a code to reverse a string.

# s[::-1]
# Example usage:
s = "Hello World!"
s[::-1]
'!dlroW olleH'

# %%
# Write a code to count the number of vowels in a string.

# Vowels = "aeiou"
def count_vowels(input_string):
    # Define a set of vowels
    vowels = "aeiouAEIOU"
    
    # Initialize a counter for vowels
    count = 0
    
    # Iterate through each character in the string
    for char in input_string:
        if char in vowels:
            count += 1
            
    return count

# Example usage
input_string = "Hello, World!"
vowel_count = count_vowels(input_string)
print(f"The number of vowels in '{input_string}' is: {vowel_count}")
The number of vowels in 'Hello, World!' is: 3

# %%
# Write a code to convert a given string to upper or lower case.

#text.lower()
#text.upper()

# Example usage:
text = "Hello World"
text.lower()
'hello world'

text = "Hello World"
text.upper()
'HELLO WORLD'

# %%
# Write a code to concatenate two strings without using the + operator.


# " ".join(words)

#Example usage:
words = ["Hello", "World"]
" ".join(words)
'Hello World'

# %%
# Write a code to check if a given string is a palindrome or not.

# def is_palindrome(input_string):
    # Normalize the string: remove spaces and convert to lowercase
    normalized_string = ''.join(input_string.split()).lower()
    
    # Check if the normalized string is equal to its reverse
    return normalized_string == normalized_string[::-1]

# Example usage
input_string = "A man a plan a canal Panama"
if is_palindrome(input_string):
    print(f'"{input_string}" is a palindrome.')
else:
    print(f'"{input_string}" is not a palindrome.')
"A man a plan a canal Panama" is a palindrome.

# %%
# Write a code to check if two given strings are anagrams of each other.

# def are_anagrams(str1, str2):
    # Normalize the strings: remove spaces and convert to lowercase
    normalized_str1 = ''.join(str1.split()).lower()
    normalized_str2 = ''.join(str2.split()).lower()
    
    # Check if sorted characters of both strings are the same
    return sorted(normalized_str1) == sorted(normalized_str2)

# Example usage
string1 = "Listen"
string2 = "Silent"

if are_anagrams(string1, string2):
    print(f'"{string1}" and "{string2}" are anagrams.')
else:
    print(f'"{string1}" and "{string2}" are not anagrams.')
"Listen" and "Silent" are anagrams.

# %%
# Write a code to find all occurrences of a given substring within another string.

# def find_all_occurrences(main_string, substring):
    # Initialize a list to store the starting indices
    indices = []
    start = 0
    
    while True:
        # Find the index of the next occurrence of the substring
        start = main_string.find(substring, start)
        
        # If no more occurrences are found, break the loop
        if start == -1:
            break
        
        # Append the index to the list
        indices.append(start)
        
        # Move start up to the next character to continue searching
        start += 1

    return indices

# Example usage
main_string = "This is a test string to test the test function."
substring = "test"

occurrences = find_all_occurrences(main_string, substring)
print(f'The substring "{substring}" was found at indices: {occurrences}')
The substring "test" was found at indices: [10, 27, 32]

# %%
# Write a code to perform basic string compression using the counts of repeated characters.

# def basic_string_compression(s):
    if not s:
        return ""

    compressed_string = []
    count = 1

    # Iterate through the string to count repeated characters
    for i in range(1, len(s)):
        if s[i] == s[i - 1]:
            count += 1
        else:
            # Append the character and its count to the compressed string
            compressed_string.append(s[i - 1])
            compressed_string.append(str(count))
            count = 1  # Reset the count for the new character

    # Handle the last character and its count
    compressed_string.append(s[-1])
    compressed_string.append(str(count))

    # Join the compressed parts into a single string
    compressed_result = ''.join(compressed_string)

    # Return the compressed string, or the original if it's not shorter
    return compressed_result if len(compressed_result) < len(s) else s

# Example usage
input_string = "aabcccccaaa"
compressed_string = basic_string_compression(input_string)
print(f"Compressed string: '{compressed_string}'")
Compressed string: 'a2b1c5a3'

# %%
# Write a code to determine if a string has all unique characters.

# def has_all_unique_characters(s):
    # Normalize the string to handle case insensitivity (optional)
    s = s.lower()
    
    # Create an empty set to track seen characters
    seen_characters = set()
    
    for char in s:
        if char in seen_characters:
            return False  # Character already seen, not unique
        seen_characters.add(char)  # Add character to the set

    return True  # All characters are unique

# Example usage
input_string = "abcdefg"
result = has_all_unique_characters(input_string)

if result:
    print(f'The string "{input_string}" has all unique characters.')
else:
    print(f'The string "{input_string}" does not have all unique characters.')
The string "abcdefg" has all unique characters.

# %%
# Write a code to count the number of words in a string.

# def count_words(input_string):
    # Strip leading and trailing spaces and split the string into words
    words = input_string.strip().split()
    
    # Count the number of words
    return len(words)

# Example usage
input_string = "   This is an example string with seven words.   "
word_count = count_words(input_string)
print(f'The number of words in the string is: {word_count}')
The number of words in the string is: 7

# %%
# Write a code to remove all occurrences of a specific element from a list.

# def remove_element_from_list(original_list, element_to_remove):
    # Create a new list that includes only the elements that are not equal to element_to_remove
    return [element for element in original_list if element != element_to_remove]

# Example usage
input_list = [1, 2, 3, 4, 2, 5, 2, 6]
element = 2
result_list = remove_element_from_list(input_list, element)

print(f'Original list: {input_list}')
Original list: [1, 2, 3, 4, 2, 5, 2, 6]
print(f'List after removing {element}: {result_list}')
List after removing 2: [1, 3, 4, 5, 6]

# %%
#  Implement a code to find the second largest number in a given list of integers. 

# def find_second_largest(numbers):
    if len(numbers) < 2:
        return None  # Not enough elements to find the second largest
    
    first, second = float('-inf'), float('-inf')

    for number in numbers:
        if number > first:
            second = first  # Update second largest
            first = number   # Update largest
        elif number > second and number != first:
            second = number  # Update second largest only

    return second if second != float('-inf') else None  # Return None if no second largest

# Example usage
input_list = [10, 20, 4, 45, 99, 99]
second_largest = find_second_largest(input_list)

if second_largest is not None:
    print(f'The second largest number in the list is: {second_largest}')
else:
    print('There is no second largest number in the list.')
The second largest number in the list is: 45

# %%
# Create a code to count the occurrences of each element in a list and return a dictionary with elements as keys 
and their counts as values.

# def count_occurrences(input_list):
    occurrences = {}
    
    for element in input_list:
        if element in occurrences:
            occurrences[element] += 1  # Increment the count if the element exists
        else:
            occurrences[element] = 1     # Initialize the count if it's a new element
            
    return occurrences

# Example usage
input_list = ["apple", "banana", "apple", "orange", "banana", "apple"]
result = count_occurrences(input_list)

print(f'Occurrences of each element: {result}')
Occurrences of each element: {'apple': 3, 'banana': 2, 'orange': 1}

# %%
# Write a code to reverse a list in-place without using any built-in reverse functions. 

# def reverse_list_in_place(lst):
    left, right = 0, len(lst) - 1
    
    while left < right:
        # Swap the elements at left and right indices
        lst[left], lst[right] = lst[right], lst[left]
        # Move the pointers towards the center
        left += 1
        right -= 1

# Example usage
input_list = [1, 2, 3, 4, 5]
print("Original list:", input_list)
Original list: [1, 2, 3, 4, 5]


reverse_list_in_place(input_list)
print("Reversed list:", input_list)
Reversed list: [5, 4, 3, 2, 1]

# %%
# Implement a code to find and remove duplicate from a list while preserving the original order of elements.

# def remove_duplicates(input_list):
    seen = set()  # Set to keep track of seen elements
    result = []   # List to store the result

    for element in input_list:
        if element not in seen:
            seen.add(element)  # Add to the seen set
            result.append(element)  # Add to the result list

    return result

# Example usage
input_list = [1, 2, 2, 3, 4, 1, 5, 3]
result_list = remove_duplicates(input_list)

print("Original list:", input_list)
Original list: [1, 2, 2, 3, 4, 1, 5, 3]

print("List after removing duplicates:", result_list)
List after removing duplicates: [1, 2, 3, 4, 5]

# %%
# Create a code to check if a given list is sorted (either in ascending or descending order) or not.

# def is_sorted(lst):
    if len(lst) < 2:
        return True  # A list with 0 or 1 element is considered sorted
    
    ascending = True
    descending = True
    
    for i in range(1, len(lst)):
        if lst[i] < lst[i - 1]:
            ascending = False
        elif lst[i] > lst[i - 1]:
            descending = False
    
    return ascending or descending

# Example usage
print(is_sorted([1, 2, 3, 4, 5]))  # True (ascending)
print(is_sorted([5, 4, 3, 2, 1]))  # True (descending)
print(is_sorted([1, 3, 2, 4, 5]))  # False (not sorted)
print(is_sorted([1]))               # True (single element)
print(is_sorted([]))                # True (empty list)

# %%
# Write a code to merge two sorted lists into a single sorted list.

# def merge_sorted_lists(list1, list2):
    merged_list = []
    i, j = 0, 0

    # Traverse both lists
    while i < len(list1) and j < len(list2):
        if list1[i] < list2[j]:
            merged_list.append(list1[i])
            i += 1
        else:
            merged_list.append(list2[j])
            j += 1
    
    # Append remaining elements of list1 (if any)
    while i < len(list1):
        merged_list.append(list1[i])
        i += 1
    
    # Append remaining elements of list2 (if any)
    while j < len(list2):
        merged_list.append(list2[j])
        j += 1
    
    return merged_list

# Example usage
list1 = [1, 3, 5, 7]
list2 = [2, 4, 6, 8]
merged_result = merge_sorted_lists(list1, list2)

print("Merged sorted list:", merged_result)
Merged sorted list: [1, 2, 3, 4, 5, 6, 7, 8]

# %%
# Implement a code to find the intersection of two given lists.

# def intersection(list1, list2):
    # Convert both lists to sets and find the intersection
    return list(set(list1) & set(list2))

# Example usage
list1 = [1, 2, 3, 4, 5]
list2 = [4, 5, 6, 7, 8]
result = intersection(list1, list2)
print(result)  
# Output: [4, 5]

# %%
#  Create a code to find the union of two lists without duplicates.

# def union(list1, list2):
    # Convert both lists to sets and combine them
    return list(set(list1) | set(list2))

# Example usage
list1 = [1, 2, 3, 4, 5]
list2 = [4, 5, 6, 7, 8]
result = union(list1, list2)
print(result)  # Output: [1, 2, 3, 4, 5, 6, 7, 8]

# %%
# Write a code to shuffle a given list randomly without using any built-in shuffle functions.

# import random
random
<module 'random' from '/opt/conda/lib/python3.10/random.py'>

def shuffle_list(input_list):
    # Create a copy of the input list to avoid modifying the original
    shuffled_list = input_list[:]
    n = len(shuffled_list)
    
    # Implement the Fisher-Yates shuffle
    for i in range(n - 1, 0, -1):
        # Generate a random index from 0 to i
        j = random.randint(0, i)
        
        # Swap elements at indices i and j
        shuffled_list[i], shuffled_list[j] = shuffled_list[j], shuffled_list[i]

    return shuffled_list

# Example usage
original_list = [1, 2, 3, 4, 5]
shuffled = shuffle_list(original_list)
print("Original list:", original_list)
print("Shuffled list:", shuffled)

# %%
# Write a code thot takes two tuples as input and returns a new tuple containing elements thot ore common to
both input tuples.

# def common_elements(tuple1, tuple2):
    # Convert both tuples to sets and find the intersection
    common_set = set(tuple1) & set(tuple2)
    
    # Return the common elements as a new tuple
    return tuple(common_set)

# Example usage
tuple1 = (1, 2, 3, 4, 5)
tuple2 = (4, 5, 6, 7, 8)
result = common_elements(tuple1, tuple2)
print(result)  # Output: (4, 5) or (5, 4) since sets do not maintain order
